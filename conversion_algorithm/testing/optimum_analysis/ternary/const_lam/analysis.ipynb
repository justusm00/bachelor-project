# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# #### Measure dependence of optimum on $T_{max}$ for $\alpha=0.85$

# %%
tmax=np.loadtxt("sa/var_tmax/tmax.csv")
opt_no_sa=np.loadtxt("no_sa/opt.csv")
print(f"Optimum without simulated annealing: {opt_no_sa.mean()}")
n_sim=100
opt_sa=np.loadtxt(f"sa/var_tmax/opt.csv")[:]
opt_sa=opt_sa.reshape(int(len(opt_sa)/n_sim),n_sim)
print(opt_sa.mean(axis=1))
plt.scatter(tmax,opt_sa.mean(axis=1))
# Out:
# Optimum without simulated annealing: 0.06006564000000001
# [0.05870021 0.05939051 0.05870702 0.05934255 0.05912217 0.05916033
#  0.0592067  0.05921042 0.05927185 0.05882574 0.0590512  0.05888649
#  0.05867576 0.05886697 0.05898214 0.05886942 0.05931288 0.05897482
#  0.05878141 0.05865277 0.05875229 0.05847793 0.05882725 0.05888677
#  0.05926531 0.05847462 0.05905601 0.05932727 0.05957948 0.05922378
#  0.05891486 0.05856748 0.05912781 0.05925339 0.05896366 0.05917676
#  0.05883106 0.05885938 0.05928193 0.05915326 0.05929167 0.05921259
#  0.0596963  0.05871408 0.05908567 0.05908226 0.05892423 0.0587179
#  0.05890586 0.05921863]

# %% [markdown]
# #### Measure dependence of optimum on $\alpha$ for $T_{max}=5$

# %%
alpha=np.loadtxt("sa/var_alpha/alpha.csv")
opt_no_sa=np.loadtxt("no_sa/opt.csv")
print(f"Optimum without simulated annealing: {opt_no_sa.mean()}")
n_sim=10
opt_sa=np.loadtxt(f"sa/var_alpha/opt.csv")[:]
print(opt_sa.shape)
opt_sa=opt_sa.reshape(int(len(opt_sa)/n_sim),n_sim)
print(opt_sa.mean(axis=1))
plt.scatter(alpha,opt_sa.mean(axis=1))
# Out:
# Optimum without simulated annealing: 0.06006564000000001
# (100,)
# [0.0602474 0.0599189 0.0589891 0.0576899 0.0581717 0.0592885 0.0587618
#  0.0583575 0.0598065 0.0584463]

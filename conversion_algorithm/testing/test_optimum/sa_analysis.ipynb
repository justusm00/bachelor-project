# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
lam_per=np.arange(1,10,1)*2/8
thermal_noise=0.014 ##standard deviation of density obtained from simulation without umbrella field
opt=np.array([])
for i in range(1,10):
    opt=np.append(opt,np.mean(np.loadtxt(f"opt_{i}.txt")))
print(opt)
plt.xlabel("$\lambda$ $[R_e]$")
plt.ylabel("$\Delta/\Delta_0$")
plt.grid()
plt.plot(lam_per,opt/thermal_noise)
plt.savefig("optimum_periodicity.pdf")
# Out:
# [0.05996258 0.04130434 0.02774174 0.01565303 0.01027733 0.01077549
#  0.00608096 0.00607891 0.00670498]
